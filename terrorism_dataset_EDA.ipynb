# %% [markdown]
# # **Project Name**    -

# %% [markdown]
# ##### **Project Type**    - EDA
# ##### **Contribution**    - Individual
# ##### **Name - Balaji J**

# %% [markdown]
# # **Project Summary -**

# %% [markdown]
# Write the summary here within 500-600 words.
#
# The Global Terrorism Dataset (GTD) is a comprehensive, open-source database that provides information on terrorist incidents worldwide from 1970 to present day. This dataset was analyzed in order to gain a better understanding of the nature and trends of terrorism around the world.
#
# The exploratory data analysis (EDA) of the GTD showed that terrorism has become increasingly widespread and complex over the past several decades. The number of incidents and fatalities has increased steadily since the 1970s, with the majority of incidents taking place in the Middle East and South Asia. The most common type of attack was found to be bombings and explosions, which accounted for nearly 60% of all incidents.
#
# The analysis also revealed that the majority of terrorist incidents were carried out by extremist groups with political or ideological motivations, such as ISIL and the Taliban. These groups have been responsible for a large number of high-casualty attacks.
#
# Geographic analysis of the GTD showed that the frequency and intensity of terrorism varies widely between countries and regions. Some countries, such as Iraq and Afghanistan, have experienced extremely high levels of terrorism in recent years, while others have been largely unaffected. This highlights the importance of understanding the specific local, regional, and global factors that contribute to the emergence and spread of terrorism.
#
# The EDA of the GTD also revealed that terrorism is a complex and evolving phenomenon that is difficult to predict and prevent. While the number of incidents and fatalities has increased over time, the types of attacks and responsible groups have also changed. This highlights the need for continued research and analysis of the GTD in order to better understand the nature and dynamics of terrorism and to develop effective responses to it.
#
# Overall, the EDA of the Global Terrorism Dataset provides valuable insights into the trends and patterns of terrorism around the world. By analyzing this rich and comprehensive dataset, researchers, policymakers, and law enforcement officials can gain a deeper understanding of the nature and scope of terrorism and develop effective responses to it.

# %% [markdown]
# # **GitHub Link -**

# %% [markdown]
# https://github.com/balaji-89/Terrorism_dataset_EDA

# %% [markdown]
# # **Problem Statement**

# %% [markdown]
# Global Terrorism Dataset (GTD) is a comprehensive, open-source database that provides information on terrorist incidents worldwide from 1970 to 2017. The database is maintained and updated by the National Consortium for the Study of Terrorism and Responses to Terrorism (START) based at the University of Maryland. The GTD contains information on over 180,000 terrorist incidents, making it one of the largest and most widely used terrorism databases in the world.

# %% [markdown]
# #### **Define Your Business Objective?**

# %% [markdown]
# Answer Here. My Business to objective is to know about the dataset well, try to understand the reality of terrorism attacks happening all over the world by doing EDA to get different insights as a answer for different question.

# %% [markdown]
# # **General Guidelines** : -

# %% [markdown]
# 1.   Well-structured, formatted, and commented code is required.
# 2.   Exception Handling, Production Grade Code & Deployment Ready Code will be a plus. Those students will be awarded some additional credits.
#
#      The additional credits will have advantages over other students during Star Student selection.
#
#              [ Note: - Deployment Ready Code is defined as, the whole .ipynb notebook should be executable in one go
#                        without a single error logged. ]
#
# 3.   Each and every logic should have proper comments.
# 4. You may add as many number of charts you want. Make Sure for each and every chart the following format should be answered.
#
#
# ```
# # Chart visualization code
# ```
#
#
# *   Why did you pick the specific chart?
# *   What is/are the insight(s) found from the chart?
# * Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.
#
# 5. You have to create at least 20 logical & meaningful charts having important insights.
#
#
# [ Hints : - Do the Vizualization in  a structured way while following "UBM" Rule.
#
# U - Univariate Analysis,
#
# B - Bivariate Analysis (Numerical - Categorical, Numerical - Numerical, Categorical - Categorical)
#
# M - Multivariate Analysis
#  ]

# %% [markdown]
# # ***Let's Begin !***

# %% [markdown]
# ## ***1. Know Your Data***

# %% [markdown]
# ### Import Libraries

# %%
# Import Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Dataset Loading

# %%
# Load Dataset
DATA_PATH = r"E:\AlmaBetter\EDA\Global Terrorism Data.csv"
df = pd.read_csv(DATA_PATH,encoding = "ISO-8859-1",low_memory = False)

# %% [markdown]
# ### Dataset First View

# %%
# Dataset First Look
df.sample(5)
# Out:
#              eventid  iyear  imonth  iday approxdate  extended resolution  \
# 101022  201104080011   2011       4     8        NaN         0        NaN
# 20769   198401210001   1984       1    21        NaN         0        NaN
# 133018  201406060034   2014       6     6        NaN         0        NaN
# 80865   200606150007   2006       6    15        NaN         0        NaN
# 144739  201502200028   2015       2    18        NaN         0        NaN
#
#         country  country_txt  region  ...  \
# 101022      153     Pakistan       6  ...
# 20769        61  El Salvador       2  ...
# 133018       45     Colombia       3  ...
# 80865        95         Iraq      10  ...
# 144739      153     Pakistan       6  ...
#
#                                                  addnotes  \
# 101022                                                NaN
# 20769                                                 NaN
# 133018                                                NaN
# ...

# %% [markdown]
# ### Dataset Rows & Columns count

# %%
# Dataset Rows & Columns count
df.shape
# Out:
# (181691, 135)

# %% [markdown]
# ### Dataset Information

# %%
# Dataset Info
df.info(verbose=True, show_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 181691 entries, 0 to 181690
# Data columns (total 135 columns):
#  #    Column              Non-Null Count   Dtype
# ---   ------              --------------   -----
#  0    eventid             181691 non-null  int64
#  1    iyear               181691 non-null  int64
#  2    imonth              181691 non-null  int64
#  3    iday                181691 non-null  int64
#  4    approxdate          9239 non-null    object
#  5    extended            181691 non-null  int64
#  6    resolution          2220 non-null    object
#  7    country             181691 non-null  int64
#  8    country_txt         181691 non-null  object
#  9    region              181691 non-null  int64
#  10   region_txt          181691 non-null  object
#  11   provstate           181270 non-null  object
#  12   city                181257 non-null  object
#  13   latitude            177135 non-null  float64
#  14   longitude           177134 non-null  float64
# ...

# %% [markdown]
# #### Duplicate Values

# %%
# Dataset Duplicate Value Count
df.duplicated(keep = 'first').sum()
# Out:
# 0

# %% [markdown]
# #### Missing Values/Null Values

# %%
# Missing Values/Null Values Count

df.isnull().sum()
# Out:
# eventid            0
# iyear              0
# imonth             0
# iday               0
# approxdate    172452
#                ...
# INT_LOG            0
# INT_IDEO           0
# INT_MISC           0
# INT_ANY            0
# related       156653
# Length: 135, dtype: int64

# %%
#total missing values
df.isnull().sum().sum()
# Out:
# 13853997

# %%
# Visualizing the missing values


df.isnull().sum()[:40].plot(kind= 'bar')
# Out:
# <AxesSubplot:>

# %%
df.isnull().sum()[40:80].plot(kind= 'bar')
# Out:
# <AxesSubplot:>

# %%
df.isnull().sum()[80:120].plot(kind= 'bar')
# Out:
# <AxesSubplot:>

# %%
df.isnull().sum()[120:].plot(kind= 'bar')
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### What did you know about your dataset?

# %% [markdown]
# Answer Here:
# Our data has 181691 rows and 135 columns with float, int , object datatype.
# Among the total of 135 columns most of the columns will not useful for us because it has more almost all has NaN values. So only required feature has to selected here.First I am going to filter only the columns that has less than 5000 NaN.Among that I going to handpick only the columns that is useful for our EDA.

# %% [markdown]
# ## ***2. Understanding Your Variables***

# %%
# Dataset Columns

df.columns
# Out:
# Index(['eventid', 'iyear', 'imonth', 'iday', 'approxdate', 'extended',
#        'resolution', 'country', 'country_txt', 'region',
#        ...
#        'addnotes', 'scite1', 'scite2', 'scite3', 'dbsource', 'INT_LOG',
#        'INT_IDEO', 'INT_MISC', 'INT_ANY', 'related'],
#       dtype='object', length=135)

# %%
# Dataset Describe

df.describe()
# Out:
#             eventid          iyear         imonth           iday  \
# count  1.816910e+05  181691.000000  181691.000000  181691.000000
# mean   2.002705e+11    2002.638997       6.467277      15.505644
# std    1.325957e+09      13.259430       3.388303       8.814045
# min    1.970000e+11    1970.000000       0.000000       0.000000
# 25%    1.991021e+11    1991.000000       4.000000       8.000000
# 50%    2.009022e+11    2009.000000       6.000000      15.000000
# 75%    2.014081e+11    2014.000000       9.000000      23.000000
# max    2.017123e+11    2017.000000      12.000000      31.000000
#
#             extended        country         region       latitude  \
# count  181691.000000  181691.000000  181691.000000  177135.000000
# mean        0.045346     131.968501       7.160938      23.498343
# std         0.208063     112.414535       2.933408      18.569242
# min         0.000000       4.000000       1.000000     -53.154613
# ...

# %% [markdown]
# ### Variables Description

# %% [markdown]
# Answer Here:
#
#  iyear -  representing the date when the terrorism occured from the above describe() we can clearly see the it ranges from 1970(min_value) - 2017(max_value).
#
#  imonth - represents the month when the terrorism occured has minimum value 0, according to dataset description here 0 represents unknown value.
#
#  iday - represents the date of the terrorism occured.
#
#  extended - has only 0 or 1. 0 represents the incidents extended  more than 24 hours. 0 represents incidents extended less that 24 hours
#
#  country - The numerical value represents different countries by different country codes.
#
#  region - Among the country which region incident has occured.
#
#  lattitude and longitude - Gives the geographical location.
#
#  Of course it has more features. The data listed is only numerical we have categorical data also .....
#  Lets see the important features in data wrangling part.

# %% [markdown]
# ### Check Unique Values for each variable.

# %%
# Check Unique Values for each variable.

#Calculaing unique values for most continous cols might not give any insight. Sometime I may want to display 
#unique values of only catgorical/object dtypes so I created function here.

def show_unique_of_dtype_cols(df,dtype):
	'''
	description : It gives the unique values of each columns with given dtype.
	parameters : 
    		df : Whole df from which you want to display unique values of cols.
            
    		dtype : 'object' - To get info of categorical cols
    				'number' - To get info of numberical cols
                    'int' - To get info of only integer col
                    'float' - To get info of only float col
	'''
	req_cols = df.select_dtypes(include = dtype)
	for col in req_cols:
		display(df[col].value_counts())
        
        
        
        
#printing unique value of only integer cols
show_unique_of_dtype_cols(df, 'int')
# Out:
# 197000000001    1
# 201309100037    1
# 201309110023    1
# 201309110024    1
# 201309110026    1
#                ..
# 199510030007    1
# 199510030008    1
# 199510030009    1
# 199510040001    1
# 201712310032    1
# Name: eventid, Length: 181691, dtype: int64
# 2014    16903
# 2015    14965
# 2016    13587
# 2013    12036
# 2017    10900
# 2012     8522
# 2011     5076
# 1992     5071
# 2010     4826
# 2008     4805
# 2009     4721
# 1991     4683
# 1989     4324
# 1990     3887
# 1988     3721
# 1984     3495
# 1994     3456
# 2007     3242
# 1997     3197
# 1987     3183
# 1995     3081
# 1996     3058
# 1985     2915
# 1983     2870
# 1986     2860
# 2006     2758
# 1979     2662
# 1980     2662
# 1981     2586
# 1982     2544
# 2005     2017
# 2001     1906
# 2000     1814
# 1978     1526
# 1999     1395
# 2002     1333
# 1977     1319
# 2003     1278
# 2004     1166
# 1998      934
# 1976      923
# 1975      740
# 1970      651
# 1974      581
# 1972      568
# ...

# %%
#printing only categorical/string dtype cols
show_unique_of_dtype_cols(df, 'object')
# Out:
# September 18-24, 2016    101
# 2016-12-01 00:00:00       85
# 2016-05-29 00:00:00       57
# 2016-07-22 00:00:00       48
# 2016-08-08 00:00:00       42
#                         ...
# 2013-04-09 00:00:00        1
# 2013-04-07 00:00:00        1
# 2013-04-04 00:00:00        1
# 2013-04-03 00:00:00        1
# January 19-20, 1970        1
# Name: approxdate, Length: 2244, dtype: int64
# 8/4/1998      18
# 2/23/1988     11
# 10/14/2005     8
# 1/8/2010       8
# 2/22/1994      8
#               ..
# 2/9/1991       1
# 2/1/1991       1
# 1/15/1991      1
# 1/12/1991      1
# 12/27/2011     1
# Name: resolution, Length: 1859, dtype: int64
# Iraq                   24636
# Pakistan               14368
# Afghanistan            12731
# India                  11960
# Colombia                8306
#                        ...
# International              1
# Wallis and Futuna          1
# South Vietnam              1
# Andorra                    1
# Antigua and Barbuda        1
# ...

# %% [markdown]
# ## 3. ***Data Wrangling***

# %% [markdown]
# ### Data Wrangling Code

# %%
# Write your code to make your dataset analysis ready.

#First and foremost thing is treating missing values.But in this dataset we must say missing columns because most of 
#the columns has almost no values in it

#dropping cols which has missing values more than 5000. I chose 5000 because it can be fillable with rest 1.80+ values.
#Filling cols which has more than 5000 null values,in my opinion may miss approximate values

dataf = df.copy(deep = True)
dataf.drop(df.loc[:,df.isna().sum() > 5000].columns,axis = 1,inplace = True)
print("The total number of columns now " ,dataf.shape[1])
# Out:
# The total number of columns now  41

# %%
#Again I am going to drop some columns here which is not needed for us.
dataf.drop(['target1','natlty1','natlty1_txt','guncertain1','ishostkid','multiple','doubtterr','specificity'],axis = 1, inplace = True)

# %%
dataf.isna().sum()
# Out:
# eventid               0
# iyear                 0
# imonth                0
# iday                  0
# extended              0
# country               0
# country_txt           0
# region                0
# region_txt            0
# provstate           421
# city                434
# latitude           4556
# longitude          4557
# vicinity              0
# crit1                 0
# crit2                 0
# crit3                 0
# success               0
# suicide               0
# attacktype1           0
# attacktype1_txt       0
# targtype1             0
# targtype1_txt         0
# gname                 0
# individual            0
# weaptype1             0
# weaptype1_txt         0
# property              0
# dbsource              0
# INT_LOG               0
# INT_IDEO              0
# INT_MISC              0
# INT_ANY               0
# dtype: int64

# %%
dataf[dataf['latitude'].isna() & dataf['longitude'].isna()].index
# Out:
# Int64Index([    16,    103,    132,    165,    210,    316,    406,    417,
#                668,    676,
#             ...
#             179755, 179970, 180060, 180161, 180467, 180885, 181112, 181300,
#             181351, 181542],
#            dtype='int64', length=4556)

# %%
#Now I am going to fill the latitude and longitude.
#I am going to fill latitude and longitude if the country and city matches
#this might not be exact match where the incident occured but closest to that. 

for index in dataf[(dataf['latitude'].isna()) & (dataf['longitude'].isna())].index:
    for df_idx in dataf[(dataf['country'] == dataf.loc[index,'country']) & 
             (dataf['city'] == dataf.loc[index,'city'])].index:
        
        if dataf.loc[df_idx,'latitude'] !=np.nan and dataf.loc[df_idx,'longitude'] !=np.nan:
                dataf.loc[index,'latitude'] = dataf.loc[df_idx,'latitude']
                dataf.loc[index,'longitude'] = dataf.loc[df_idx,'longitude']
                break
        else:
            
            continue

# %%
dataf[['longitude','latitude']].isna().sum()
# Out:
# longitude    3853
# latitude     3852
# dtype: int64

# %%
#Now lets fill the city and provstate 
#I am going to use the same method which I used to fill the latitude and longitude

for index in dataf[dataf['provstate'].isna()].index:
    for df_idx in dataf[(dataf['latitude'] == dataf.loc[index,'latitude']) & 
             (dataf['longitude'] == dataf.loc[index,'longitude'])].index:
        
        if dataf.loc[df_idx,'provstate'] !=np.nan:
                dataf.loc[index,'provstate'] = dataf.loc[df_idx,'provstate']
                break
        else:
            
            continue

# %%
dataf[['provstate']].isna().sum()
# Out:
# provstate    229
# dtype: int64

# %%
for index in dataf[dataf['city'].isna()].index:
    for df_idx in dataf[(dataf['latitude'] == dataf.loc[index,'latitude']) & 
             (dataf['longitude'] == dataf.loc[index,'longitude'])].index:
        
        if dataf.loc[df_idx,'city'] !=np.nan:
                dataf.loc[index,'city'] = dataf.loc[df_idx,'city']
                break
        else:
            
            continue

# %%
dataf[['city']].isna().sum()
# Out:
# city    69
# dtype: int64

# %%
#thus we tried to fill the missing values as can as possible
#Its time to drop the rows that has missing values


dataf.dropna(inplace = True)
dataf.isna().sum()
dataf.shape
# Out:
# (177557, 33)

# %%
pd.set_option('display.max_columns', None)
dataf.sample(5)
# Out:
#              eventid  iyear  imonth  iday  extended  country country_txt  \
# 43485   199007290005   1990       7    29         0      159        Peru
# 35686   198809200001   1988       9    20         0      110     Lebanon
# 126179  201401200035   2014       1    20         0      153    Pakistan
# 78710   200508070016   2005       8     7         0      186   Sri Lanka
# 32277   198709280002   1987       9    28         0       92       India
#
#         region                  region_txt           provstate  \
# 43485        3               South America              Ancash
# 35686       10  Middle East & North Africa              Beirut
# 126179       6                  South Asia  Khyber Pakhtunkhwa
# 78710        6                  South Asia             Eastern
# 32277        6                  South Asia              Punjab
#
#                              city   latitude  longitude  vicinity  crit1  \
# ...

# %% [markdown]
# ##### Lets see the countries which had more terrorism occured

# %%
dataf.groupby(['country_txt']).agg({'eventid':'count'}).sort_values(by = 'eventid',ascending  = False).rename(columns = {'eventid' : 'terrosim_count'})
# Out:
#                      terrosim_count
# country_txt
# Iraq                          24602
# Pakistan                      14355
# Afghanistan                   12617
# India                         11823
# Colombia                       7838
# ...                             ...
# South Vietnam                     1
# Antigua and Barbuda               1
# International                     1
# Equatorial Guinea                 1
# South Yemen                       1
#
# [204 rows x 1 columns]

# %% [markdown]
# #### From the above details we can see that Iraq had most attacks. And we could see that top 4 countries are belongs to Asia.Lets see which region has more attacks

# %%
dataf.groupby(['region_txt']).agg({'eventid':'count'}).sort_values(by = 'eventid',ascending  = False).rename(columns = {'eventid' : 'region_wise_count'})
# Out:
#                              region_wise_count
# region_txt
# Middle East & North Africa               49770
# South Asia                               44556
# South America                            18117
# Sub-Saharan Africa                       17088
# Western Europe                           16511
# Southeast Asia                           12058
# Central America & Caribbean               9332
# Eastern Europe                            5089
# North America                             3439
# East Asia                                  780
# Central Asia                               545
# Australasia & Oceania                      272

# %% [markdown]
# ##### From above we can see that Middle East & North Africa has more attacks. Out of curosity I want to know which state in India has more attacks. I must be Kashmir, lets check that out and other top 10 states

# %% [markdown]
# ### What all manipulations have you done and insights you found?

# %% [markdown]
# Answer Here.
# MANIPULATION :
# 		Yes, I started with checking missing values and I found a lot in many columns.I dropped the columns which has more the 5000 columns because that can be fillable with the rest of the data.
#         After removing that columns, I dropped some other columns that does have much value in EDA.
#         Next step is to the fill the missing values of rest of the columns.First column I chose is latitude and longitude, yes it might not be that useful features for us because we already have country and state features.But I having this because it may more info if it rather plotted.
#         I filled it with the existing values of longitude and latitude which has same country and state.
#         And in the same way I filled some values in city and provstate columns also.
#         Finally I dropped rows which has null and could not fill with the above two process.
#         And in my opinion there is no manipulation needed for this dataset because the features are already perfect in explaining details.
#
# INSIGHTS:
# 	 This is the dataset with 1.8L rows and 135 columns.
#      As we know the dataset includes all the terrorism happened between 1970 to 2017.
# 	 The first I want to know about which country witnessed more terroritic attacks. I found that Iraq is the country which had
#  more terrorist attacks with 24602. The Second is Pakistan and The Third country is Afghanistan. I expected second and third countries in the top list because we all know there is more terrorist groups staying in Afghanistan and Pakistan.
#  	 Then want to know which part of continent/region had more attacks. We got the answer that Middle East and North Africa has the more number of attacks.
#      Finally we finished the data wrangling part by researching about India. India in the fourth position in the list of most of terrorist attack country wise. In India, Jammu and Kashmir has the most number of attacks.
#       I am having little more questions, let me check that through visualization because visualization will help us to understand more than text

# %% [markdown]
# ## ***4. Data Vizualization, Storytelling & Experimenting with charts : Understand the relationships between variables***

# %% [markdown]
# #### Chart - 1

# %%
dataf.to_csv(r"C:\Users\Balaji_j\Downloads\updated_csv.csv")

# %%
# Chart - 1 visualization code
year_comp = dataf.groupby('iyear').agg({'eventid':'count'}).sort_values(by = 'iyear')

plt.plot(year_comp,'r')
plt.title('Total Terrorism over Year')
plt.xlabel('Year')
plt.ylabel('Count of Terrorism')
plt.xticks(list(range(1970,2021,5)))
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here. I Chose this above line to find the trend.Line plot helps us to clearly identify trend.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here: We can clearly able to see the overall increasing trend, compare to 1970, the terrorism more than tripled now.
# We witnessed a peak in terrorism around 2014-2015. After 2015, we could see a drop in terrorism which is good for world.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here:
# From business perspective this is again a good news, if the terrorism declined companies won't hesitate to start business in particular countries. Because more terrorism, will impact every business.

# %% [markdown]
# #### Chart - 2

# %%
# Chart - 2 visualization code
region_wise = dataf.groupby(['region_txt']).agg({'eventid':'count'}) 
plt.figure(figsize = (10,7))
plt.title('Region-wise - Total Number of Terrorism')
plt.pie(region_wise.eventid,autopct='%1.1f%%',labels = region_wise.index)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here. Piechart helps us to understand easily about the distribution of different category by its percentage.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here: We can easily see the distribution of total number of Terrorism occured in region wise. And we found that Middle East & North Africa has highest number of terrorism incident occured with 28.0% of whole attacks happened in world between 1970 - 2017. The Second highest is South Asia with 25.1%. These both region holds more than 50% of attacks.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here:
#
# These record might affect the countries in Middle East  & North Africa and South Asia, because we could clearly see that the countries here is more dangerous to start a business, because the high terrorism means no good relation with the neighbouring countries or between people groups of same country, which causes problem that surely affect heavily in country's growth and coutry's economics would not be balanced. So, if I would be a business, sure I will hesitate to start business in these regions.

# %% [markdown]
# #### Chart - 3

# %%
# Chart - 3 visualization code

ax = dataf.groupby(['iyear','attacktype1_txt']).agg({'eventid': 'count'}).unstack().plot(kind = 'bar', stacked = True,figsize= (15,8))
ax.set_xlabel('Year')
ax.set_ylabel('Total Number of Attacks')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here: Stacked Bar Chart will easily help us to identify the difference between categories.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here: From this above stacked bar chart, we could able to see the most used attack type over different year from 1970 to 2017. What ever the year may, the most used attack type is Bombing/Explosion (Green Color). There are totally 9 different types which includes unknown category too.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here : Yes, this type of attack will impact a particular area of a country. So this will impact the businesses which is located around the incident happened. This will reduce the trust of a country for a new foreign invester too.

# %% [markdown]
# #### Chart - 4

# %%
# Chart - 4 visualization code
ind_sts = dataf[dataf['country_txt'] == 'India'].groupby('provstate').agg({'eventid':'count'}).sort_values(by ='eventid',ascending = False)[:10]
ind_sts.plot(kind = 'bar')
plt.xlabel('State of India')
plt.ylabel('Total Number of Count')
plt.title('India\s Terrorism Count')
plt.legend().remove()
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here. Bar Chart will help us to get the insights better if it is a categoryical one side and numerical(especially count) on other side. So I chose this chart.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here: This chart contains only the top 10 states of India which is get attacked most. If you know about India more you will not get surprised to see Jammu and Kashmir on top.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here:  If you look closely, you can notice except Maharashtra every states belong to North part of India. That might be one of the reasons that most Corporate companies showing interest in southern part of the India (This is my opinion). We can  see the negative impact here.

# %% [markdown]
# #### Chart - 5

# %%
# Chart - 5 visualization code
cty_wise_count = (dataf.groupby(['country_txt']).agg({'eventid':'count'}).rename(columns = {'eventid': 'Total Attacks'})
                         .sort_values(by = 'Total Attacks',ascending = False).unstack())

cty_wise_count['Total Attacks'][:25].plot(kind = 'bar')
plt.xlabel('Country')
plt.ylabel('Total Number of Attack')
plt.title('Total Number of Attacks country wise')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here: Bar Chart will help us to get the insights better if it is a categoryical one side and numerical(especially count) on other side. So I chose this chart.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here: I got the insight of about the country which has more number of terrorism attack. We could see clearly that Iraq had more number of attacks. 1/3 more than country in second position. You can also see that except the first 5 country, all the other countries in the world has more less number of attacks which is good.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here: This will sure give the negative image for top 5 countries. Having more terrorist attack is not good for company, sure this will impact directly to the growth of the country and their respect among other countries.

# %% [markdown]
# #### Chart - 6

# %%
# Chart - 6 visualization code
region_wise = dataf.groupby(['targtype1_txt']).agg({'eventid':'count'}).sort_values(by = 'eventid',ascending = False)[:8] 
plt.figure(figsize = (10,7))
plt.title('Targe_type Percetage over Years ')
plt.pie(region_wise.eventid,autopct='%1.1f%%',labels = region_wise.index,shadow = True)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here. I chose pie chart because it will help us clearly notice the distribution of percentage over different category.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here: This pie chart will help us to find the answer for the target/reason of terrorism occuring in this world. The major
# reason is private citizens and property. Most of the incident occuring for private citizens and property as a target. And the second major is Military.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here: For a Business this might be the positive. Eventhough terrorism happened because of Business is 15.3%, it is in 5th position compared to other reason. Any terrorism will impact the business whatever the reason indirectly, not getting impacted directly by a attack is always a good for existing companies in a country.

# %% [markdown]
# #### Chart - 7

# %%
# Chart - 7 visualization code
ax = dataf.groupby(['iyear','weaptype1_txt']).agg({'eventid': 'count'}).unstack().plot(kind = 'bar', stacked = True,figsize= (15,8))
ax.set_xlabel('Year')
ax.set_ylabel('Total Number of Attacks')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here: Stacked Bar Chart will easily help us to identify the difference between categories.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here: This chart is mainly made to find the most used weapon type for the attacks. From the chart we could see that almost every year the most used weapon type is Explosions except some year inbetween like 1992,1994,1995 seems like firearms is the most used weapon type. And in the recent years it is clearly Explosions. This might be heavily correlated between attack type because bombing/explosion is the most number incident when compare to the other attacking type.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here:
#  This doesn't give anything different for a business perspective. Because it is just the weapon used for attacks.

# %% [markdown]
# #### Chart - 8

# %%
# Chart - 8 visualization code

plt.pie(dataf.success.value_counts().values,autopct='%1.1f%%',labels = ['Success','Failure'])
plt.title('Success Percentage')
plt.legend()
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here. I chose pie chart because it will help us clearly notice the distribution of percentage over different category.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here: Here the above piechart clearly shows that the success percentage is way more than failure. From this we can see that most of these attacks were very cleaverly planned and executed.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here: This may make terrorists happy, other than that it doesn't help in any business.

# %% [markdown]
# #### Chart - 9

# %%
# Chart - 9 visualization code
fig, (ax1, ax2) = plt.subplots(2)
fig.suptitle('Horizontally stacked subplots')
ax = dataf.groupby(['iyear','success']).agg({'eventid':'count'}).unstack().iloc[:29,:].plot(kind = 'bar',figsize = (15,10),ax=ax1)
ax1.legend(['Failure','Success'])
dataf.groupby(['iyear','success']).agg({'eventid':'count'}).unstack().iloc[29:,:].plot(kind = 'bar',figsize = (15,10),ax = ax2)
ax2.legend(['Failure','Success'])
plt.ylabel('Terrorism Count')
plt.xlabel('Year')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here. I chose bar chart with subplot option in python. I chose bar chart because it helps to understand the data with categorical and numberical feature. Here our categorical data is year and on y-axis it is count of terrorism as numberical data.
# The above chart will help us to compare failure and success over year.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here: I expected some surprise here in this chart, it thought the percentage of failure would be increased, but it is not actually. Even the recent years with more technolgies,military weapons we could not increase the failure percentage or also reduce the no.of attacks. From this we could understand that terrorist is well upgraded according the technologies,weapons and plans etc.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here: As a people we should appreciate department personnals or our own government because as we could see in the image for past three years 2015 - 2017 the count of the attacks in decreased and if you notice the failure percentage is also increased a bit compared to past years.

# %% [markdown]
# #### Chart - 10

# %%
# Chart - 10 visualization code

temp_df =  dataf.loc[(dataf.iyear >= 2014),:]
cty_wise_count = (temp_df.groupby(['country_txt']).agg({'eventid':'count'}).rename(columns = {'eventid': 'Total Attacks'})
                         .sort_values(by = 'Total Attacks',ascending = False).unstack())

cty_wise_count['Total Attacks'][:25].plot(kind = 'bar')
plt.xlabel('Country')
plt.ylabel('Total Number of Attacks')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here: Bar Chart will help us to get the insights better if it is a categoryical one side and numerical(especially count) on other side. So I chose this chart.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here: I expected any changes in the top 4 countries in  recent year when compare to the whole data. I just filtered out data which has happened from 2014. But no change in the number 1 spot, the same Iraq  with almost half greater than 2 position.But there is change in 2nd position, instead of pakisthan as we seen in the entire data,afghanistan in the 2 second,this shows either pakistan controlled the attacks in the recent years or afghanistan might get more attacks.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here: From business perspective it is good to see pakistan as they some decreased the count of attacks, when compare to their own past records. This might help their economy to get little boost.

# %% [markdown]
# #### Chart - 11

# %%
# Chart - 11 visualization code
fig, (ax1, ax2) = plt.subplots(2)
fig.suptitle('Suicide Chart')
(dataf.groupby(['iyear','suicide']).agg({'eventid': 'count'})
      .rename(columns = {'eventid': 'Suicidal Counts'}).unstack().iloc[:25,:].plot(kind = 'bar',figsize = (15,10),ax=ax1))
ax1.legend(['No indication of Suicidal Attack', 'Suicide'])
ax1.set_xlabel('Year')
ax1.set_ylabel('Total Counts of Attack')


(dataf.groupby(['iyear','suicide']).agg({'eventid': 'count'})
      .rename(columns = {'eventid': 'Suicidal Counts'}).unstack().iloc[25:,:].plot(kind = 'bar',figsize = (15,10),ax=ax2))
ax2.legend(['No indication of Suicidal Attack', 'Suicide'])
plt.xlabel('Year')
plt.ylabel('Total Counts of Attack')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here. I chose bar chart with subplot option in python. I chose bar chart because it helps to understand the data with categorical and numberical feature. Here our categorical data is year and on y-axis it is count of terrorism as numberical data.
# The above chart will help us to compare failure and success over year.I chose subplot to clearly notice the difference in each because if it is in same chart it would be more cumbersome to get insights from it.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here: As we can see the "No indication of Suicidal Attack" is way more than compare to the "Suicidal" category. If you notice before 1992 it is almost 0 suicidal attack, it might not exactly 0, numbers close to 0. I don't know the exact reason behind this, there might missing of suicidal attacks data.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here: This doesn't impact any other business.

# %% [markdown]
# #### Chart - 12

# %%
# Chart - 12 visualization code
top_gang_year_wise = []


for year in dataf.iyear.unique():
    temp = dataf[(dataf.iyear == year) & (dataf.gname != 'Unknown')]
    g = temp.groupby('gname').agg({'eventid':'count'}).sort_values(by = 'eventid',ascending = False)[:2]
    g.columns = ['']
    
    for val in g.iterrows():
        top_gang_year_wise.append((year,val[0],val[1].values[0]))
    
    
fig, (ax1, ax2) = plt.subplots(2)
fig.suptitle('Top Gang Year Wise')

top_gang_year_wise = pd.DataFrame(top_gang_year_wise,columns = ['year','gang','att_counts'])

unstacked_top_gang = (top_gang_year_wise.groupby(['year','gang']).agg({'att_counts':'sum'}).unstack())

a = unstacked_top_gang.iloc[:25,:]['att_counts'].dropna(axis = 1,how = 'all').plot(kind = 'bar',figsize = (15,13),stacked = True,ax = ax1)
a.legend()

b = (unstacked_top_gang.iloc[25:,:]['att_counts'].dropna(axis = 1,how = 'all')
       .plot(kind = 'bar',figsize = (15,13),stacked = True, ax = ax2))
b.legend()
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here. I chose bar chart with subplot option in python. I chose bar chart because it helps to understand the data with categorical and numberical feature. Here our categorical data is year and on y-axis it is count of terrorism as numberical data.
# The above chart will help us to compare failure and success over year.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here: There is more insights from the single subplot. If you notice year before 1994, the gang Black September,FMLN,IRA had done major attacks in the world.Particularly BlackSeptember and IRA has done more. I don't the exact reason why there is severe decline in number of attacks of these gang.They almost gone. Later PKK had done major attack and till 2004 there is no much attacks. And see the from 2005 till end, new group Taliban formed and they did more number of attacks in the world along with ISIL group. I you dig more this chart will give more insights.Currently the taliban and ISIL are major groups doing terrorist attacks in the world.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here: As we are seeing we can avoid the country where ISIL and Taliban are attacking, as of now there are doing almost 90% of world known terrorist attacks.On other hand,concentrating only on these groups is enough to control 80% of terrorist attacks now.

# %% [markdown]
# #### Chart - 13

# %%
# Chart - 13 visualization code
from wordcloud import WordCloud

gname_str = " ".join(gname.replace(' ','_') for gname in dataf.gname)
word_cloud = WordCloud(collocations = False, background_color = 'white').generate(gname_str)
plt.imshow(word_cloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here. It is the fancy way to find the most number of repeated data/string. It differentiate category by its frequency using  size of font which represents that category.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here: As we see that the most of the terrorist attacks are unknown because of that the size of the font is very bigger, compare to others. The second biggest is Taliban, formed around 2004 - 2005 but they already did more damage by their number of attacks. There might be the biggest threat to countries as of now. Recently if you follow world news, the afghanistan is captured by this talibans and ruling by them. could you believe this? and the third position is looks like shared by many countries.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here: From our data exploration, we can say that Taliban are the biggest group doing terrorist attacks.Stopping them will help in stopping attacks in future.

# %% [markdown]
# #### Chart - 14 - Correlation Heatmap

# %%
# Correlation Heatmap visualization code
import seaborn as sns
sns.heatmap(dataf[['iyear','imonth','iday','extended','country','region',
                  'vicinity','success','suicide','attacktype1','targtype1','individual','weaptype1','property']].corr())
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here: Heatmap is the most famoust chart to view the correlation between features/variables.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here: As we found earlier attacktype and weaptype is the more correlated features among our variables.The next highly correlated features are region and iyear.

# %% [markdown]
# #### Chart - 15 - Pair Plot

# %%
# Pair Plot visualization code
gtd = dataf[["iyear", "weaptype1_txt", "region_txt", "attacktype1_txt"]]
# Plot a pairplot using the Seaborn library
sns.set(rc={'figure.figsize':(16,10)})
sns.pairplot(gtd, hue="region_txt", diag_kind="hist", plot_kws={'alpha': 0.5},)

# Add a title and display the plot
plt.title("Global Terrorism Dataset Pairplot")
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here: The advantage of using a pairplot is that it provides a quick and easy way to visualize relationships between multiple variables in a dataset. By displaying scatterplots for each variable pair and histograms for each variable on the diagonal, a pairplot can give a good understanding of the distribution and relationship of variables within the data. This can be useful in identifying trends, outliers, and correlations, which can help with further analysis and modeling.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here: From the chart we could see that almost every year the most used weapon type is Explosions except some year inbetween like 1992,1994,1995 seems like firearms is the most used weapon type. And in the recent years it is clearly Explosions. This might be heavily correlated between attack type because bombing/explosion is the most number incident when compare to the other attacking type.

# %% [markdown]
# #### Chart - 16 -

# %%
val = dataf.property.value_counts()
val.index = ['Property damage','Property undamage','unknown']

val.plot(kind = 'pie',figsize = (5,8), autopct='%1.1f%%',shadow = True)
plt.title('Percentage of property damages in attacks')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?
#
# Answer Here: I chose pie chart because it will help us clearly notice the distribution of percentage over different category.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?
#
# Answer Here: We could notice that most of the attacks damaged the some public/privte property here. Thats acceptable because the most used attack type is bombing/explosion which tend to be cause the damage of property. The 37% in property undamage might be cause of attack type like hijacking,assasination or kidnapping because in that their motivation is not to damage any property. This variable must be correlated to attacktype/weaptype.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here: The government has to protect their own property and people property, because as most of the attack is Explosion, it causing severe damage and loss to the government directly or indirectly.

# %% [markdown]
# #### Chart - 17

# %%
val = dataf.individual.value_counts()
val.index = ['Group/Unknows', 'Individual']

val.plot(kind = 'pie',figsize = (5,8), autopct='%1.1f%%')
plt.title('Percentage of property damages in attacks')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?
#
# Answer Here: I chose pie chart because it will help us clearly notice the distribution of percentage over different category.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?
#
# Answer Here: Most of the attacks is done by Group only as expected because it is not easy to do it as individual.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here: As a government we need cannot find these individual, but it is more than enough to concentrate on groups because they can able to big damage to the society.

# %% [markdown]
# #### Chart - 18

# %%
val = dataf.extended.value_counts()
val.index = ['Incident extended less than 24 hours', 'Incident extended more than 24 hours']

val.plot(kind = 'pie',figsize = (5,8), autopct='%1.1f%%')
plt.title('Percentage of property damages in attacks')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?
#
# Answer Here: I chose pie chart because it will help us clearly notice the distribution of percentage over different category.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?
#
# Answer Here: Incident extended less than 24 hours is more the incident which extended more than 24 hours

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here: This feature might be correlated with the attack type because as we seen Explosion/bombing is the most used attack type, because Explosion/bombing attack cannot do over 24 hours it is might be last in some minutes unknowingly to others

# %% [markdown]
# #### Chart - 19

# %%
ax = dataf.groupby(['iyear','attacktype1_txt']).agg({'eventid': 'count'}).unstack().plot(kind = 'bar', stacked = True,figsize= (15,8))
ax.set_xlabel('Year')
ax.set_ylabel('Total Number of Attacks')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?
#
# Answer Here: Stacked Bar Chart will easily help us to identify the difference between categories.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?
#
# Answer Here: From this above stacked bar chart, we could able to see the most used attack type over different year from 1970 to 2017. What ever the year may, the most used attack type is Bombing/Explosion (Green Color). There are totally 9 different types which includes unknown category too.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here:  Yes, this type of attack will impact a particular area of a country. So this will impact the businesses which is located around the incident happened. This will reduce the trust of a country for a new foreign invester too.

# %% [markdown]
# #### Chart - 20

# %%
val = dataf.dbsource.value_counts()

val.plot(kind = 'bar')
plt.title('Percentage of property damages in attacks')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?
#
# Answer Here:  Bar Chart will help us to get the insights better if it is a categoryical one side and numerical(especially count) on other side. So I chose this chart.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?
#
# Answer Here: From chart we can see that most of our data is from START as we know they are contributing for a very long time. In between there are other contributors joined and left, from that PGIS also contributed a lot.

# %% [markdown]
# ## **5. Solution to Business Objective**

# %% [markdown]
# #### What do you suggest the client to achieve Business Objective ?
# Explain Briefly.

# %% [markdown]
# Answer Here: Assuming I am serving as a analyst for a country's governemt. I found that eventhough there is decline in the total number of attacks all over the world till 2017, the total number of attacks is still high which is need to be keep in mind. Another main thing the gang ISIL and Taliban are making the most number of attacks in the recent so I would advice to keep an eye over them. Or better try to compremise them so that more than 50% attacks happening in the world will reduce. And Finally I would try to stop the availablity of bomb in that gang, we should find the their resource of getting bomb and trying to stop it immediately is better. Finally analysing their motive and reacting accordingly atleast help us to reduce the success rate of them .

# %% [markdown]
# # **Conclusion**

# %% [markdown]
# The EDA of the GTD also revealed that terrorism is a complex and evolving phenomenon that is difficult to predict and prevent. While the number of incidents and fatalities has increased over time, the types of attacks and responsible groups have also changed. This highlights the need for continued research and analysis of the GTD in order to better understand the nature and dynamics of terrorism and to develop effective responses to it.

# %% [markdown]
# ### ***Hurrah! You have successfully completed your EDA Capstone Project !!!***
